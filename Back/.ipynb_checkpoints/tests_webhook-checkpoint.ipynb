# %%
import pandas as pd
import requests

# %%
ruta_csv = "Pedidos de Kits 27-1 (Respuestas) - Respuestas de formulario 1(1).csv"
data = pd.read_csv(ruta_csv)

# %%
data = data.astype(object)
data = data.where(pd.notnull(data), None)

# %%
fila = data.iloc[3].to_dict()

# %%
print(fila)
# Out:
# {'Marca temporal': '16/8/2026 1:15:58', 'Dirección de correo electrónico': 'rodrimga080703@gmail.com', 'Inserta tu nombre de usuario de facebook': 'R2', 'Ingresa tu número de celular (sin espacios)': 5555, '¿Qué pedirás?': 'Combo', 'Color del mandil - Kit ': None, 'Tamaño de guantes (hule y nitrilo) - Kit': None, 'Número de kits.': 6.0, 'Color de mandiles - Cowmpadres [Amarillo mango]': 'Kit 1', 'Color de mandiles - Cowmpadres [Rojo]': 'Kit 2', 'Color de mandiles - Cowmpadres [Vino]': 'Kit 3', 'Color de mandiles - Cowmpadres [Blanco]': 'Kit 4', 'Color de mandiles - Cowmpadres [Negro]': 'Kit 5', 'Color de mandiles - Cowmpadres [Azul pastel]': 'Kit 6', 'Color de mandiles - Cowmpadres [Azul rey]': 'Kit 1', 'Color de mandiles - Cowmpadres [Azul marino]': 'Kit 2', 'Color de mandiles - Cowmpadres [Morado]': 'Kit 3', 'Color de mandiles - Cowmpadres [Lila]': 'Kit 4', 'Color de mandiles - Cowmpadres [Turquesa]': 'Kit 5', 'Color de mandiles - Cowmpadres [Rosa pastel]': 'Kit 6', 'Color de mandiles - Cowmpadres [Rosa barbie]': 'Kit 1', 'Color de mandiles - Cowmpadres [Verde bandera]': 'Kit 2', 'Color de mandiles - Cowmpadres [Verde militar]': 'Kit 3', 'Talla de guantes de plástico - Cowmpadres [Chicos]': 'Kit 1, Kit 5', 'Talla de guantes de plástico - Cowmpadres [Medianos]': 'Kit 2, Kit 4, Kit 6', 'Talla de guantes de plástico - Cowmpadres [Grandes]': 'Kit 3', '¿Quieres agregar un kit extra?': 'Sí', 'Color del mandil - Kextra': 'Amarillo mango', 'Tamaño de guantes (hule y nitrilo) - Kextra': 'Medianos', '¿Quieres agregar piezas sueltas (extras)?': 'Sí', 'Mandil (color) - Pieza [Amarillo mango]': 1.0, 'Mandil (color) - Pieza [Rojo]': 2.0, 'Mandil (color) - Pieza [Vino]': 3.0, 'Mandil (color) - Pieza [Blanco]': 4.0, 'Mandil (color) - Pieza [Negro]': 5.0, 'Mandil (color) - Pieza [Azul pastel]': 1.0, 'Mandil (color) - Pieza [Azul rey]': 2.0, 'Mandil (color) - Pieza [Azul marino]': 3.0, 'Mandil (color) - Pieza [Morado]': 4.0, 'Mandil (color) - Pieza [Lila]': 5.0, 'Mandil (color) - Pieza [Turquesa]': 1.0, 'Mandil (color) - Pieza [Rosa pastel]': 2.0, 'Mandil (color) - Pieza [Rosa barbie]': 3.0, 'Mandil (color) - Pieza [Verde bandera]': 4.0, 'Mandil (color) - Pieza [Verde militar]': 5.0, 'Guantes de plástico (talla) - Pieza [Chicos]': '1, 5', 'Guantes de plástico (talla) - Pieza [Medianos]': '2, 4', 'Guantes de plástico (talla) - Pieza [Grandes]': 3.0, 'Guantes de nitrilo (talla) - Pieza [Chicos]': '1, 5', 'Guantes de nitrilo (talla) - Pieza [Medianos]': '2, 4', 'Guantes de nitrilo (talla) - Pieza [Grandes]': 3.0, 'Cuchillos - Pieza': 1.0, 'Tote bag - Especial': None, '¿Quieres recibir tu pedido en una tote bag?': 'Sí, una Tote para cada kit del combo', 'Fechas': 'Lunes 7 de septiembre'}

# %%
url = "http://127.0.0.1:8000/api/v1/pipeline_sheets_kits/sheets"

# %%
try:
    respuesta = requests.post(url, json=fila)
    print(f"Código de estatus: {respuesta.status_code}")
    print(f"Respuesta del servidor: {respuesta.json()}")
except requests.exceptions.ConnectionError:
    print(f"Error de conexión")
# Out:
# Código de estatus: 200
# Respuesta del servidor: {'mensaje': 'Pedido guardado'}
